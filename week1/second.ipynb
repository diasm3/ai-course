# %%
temp

# %% [markdown]
# # MNIST 실습
#
# 이번에는 28x28 흑백 손글씨 이미지를 보고 0~9 사이의 숫자 중 어떤 숫자를 쓴 것인지 예측하는 문제를 실습합니다.
# 이번 실습에서는 GPU를 활용할 것이기 때문에, 이전 챕터에서 Colab에서 GPU를 설정하는 방법을 따라해주시길 바랍니다.
#
# GPU를 설정했으면 library들을 import합니다.

# %%
import torch
import torchvision
import torchvision.transforms as transforms
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
import numpy as np
from matplotlib import pyplot as plt

# 데이터셋 준비
transform = transforms.ToTensor()

# 훈련 데이터 로드
trainset = torchvision.datasets.MNIST(
    root='./data',
    train=True,
    download=True,
    transform=transform
)

# 테스트 데이터 로드
testset = torchvision.datasets.MNIST(
    root='./data',
    train=False,
    download=True,
    transform=transform
)

# 배치 사이즈 설정
batch_size = 256

# 데이터 로더 생성
trainloader = torch.utils.data.DataLoader(
    trainset,
    batch_size=batch_size,
    shuffle=True
)

# 테스트 데이터 로더 생성 (shuffle=False로 설정)
testloader = torch.utils.data.DataLoader(
    testset,
    batch_size=batch_size,
    shuffle=False
)

# MPS 지원 확인 (macOS)
device = torch.device("mps" if torch.backends.mps.is_available() else 
                     ("cuda" if torch.cuda.is_available() else "cpu"))
print(f"Using device: {device}")

# 분류 모델 구현 (출력 차원 변경: 1 -> 10)
class Model(nn.Module):
    def __init__(self):
        super(Model, self).__init__()
        self.fc1 = nn.Linear(28*28, 512)
        self.fc2 = nn.Linear(512, 256)
        self.fc3 = nn.Linear(256, 10)  # 출력 차원을 10으로 변경 (0-9 클래스)
        
    def forward(self, x):
        x = x.view(-1, 28*28)  # 이미지를 펼침
        x = F.relu(self.fc1(x))
        x = F.relu(self.fc2(x))
        x = self.fc3(x)  # 소프트맥스는 CrossEntropyLoss에 포함되어 있음
        return x

# 모델 초기화 및 디바이스 지정
model = Model().to(device)

# 손실 함수를 MSE에서 CrossEntropyLoss로 변경
criterion = nn.CrossEntropyLoss()

# 옵티마이저 설정
optimizer = optim.Adam(model.parameters(), lr=0.001)

# 정확도 측정 함수
def accuracy(model, dataloader):
    cnt = 0
    acc = 0
    
    for data in dataloader:
        inputs, labels = data
        inputs, labels = inputs.to(device), labels.to(device)
        
        preds = model(inputs)
        preds = torch.argmax(preds, dim=-1)
        
        cnt += labels.shape[0]
        acc += (labels == preds).sum().item()
    
    return acc / cnt

# 정확도 그래프 그리기 함수
def plot_acc(train_accs, test_accs, label1='train', label2='test'):
    x = np.arange(len(train_accs))
    
    plt.plot(x, train_accs, label=label1)
    plt.plot(x, test_accs, label=label2)
    plt.legend()
    plt.xlabel('Epochs')
    plt.ylabel('Accuracy')
    plt.title('Training and Test Accuracy')
    plt.show()

# 훈련 파라미터 설정
n_epochs = 100

# 정확도 저장 리스트
train_accs = []
test_accs = []

# 훈련 시작
for epoch in range(n_epochs):
    model.train()  # 훈련 모드 설정
    running_loss = 0.0
    
    for i, data in enumerate(trainloader, 0):
        inputs, labels = data
        inputs, labels = inputs.to(device), labels.to(device)
        
        optimizer.zero_grad()
        
        outputs = model(inputs)
        loss = criterion(outputs, labels)
        loss.backward()
        optimizer.step()
        
        running_loss += loss.item()
    
    # 에폭마다 정확도 계산
    model.eval()  # 평가 모드 설정
    with torch.no_grad():
        train_acc = accuracy(model, trainloader)
        test_acc = accuracy(model, testloader)
        
        train_accs.append(train_acc)
        test_accs.append(test_acc)
    
    print(f'Epoch {epoch+1}, Loss: {running_loss/len(trainloader):.4f}, Train Acc: {train_acc:.4f}, Test Acc: {test_acc:.4f}')

# 정확도 그래프 그리기
plot_acc(train_accs, test_accs)
# Out:
# 100%|██████████| 9.91M/9.91M [00:01<00:00, 4.98MB/s]
# 100%|██████████| 28.9k/28.9k [00:00<00:00, 147kB/s]
# 100%|██████████| 1.65M/1.65M [00:01<00:00, 1.35MB/s]
# 100%|██████████| 4.54k/4.54k [00:00<00:00, 8.62MB/s]
# Using device: mps
# Epoch 1, Loss: 0.3611, Train Acc: 0.9550, Test Acc: 0.9531
# Epoch 2, Loss: 0.1307, Train Acc: 0.9747, Test Acc: 0.9699
# Epoch 3, Loss: 0.0825, Train Acc: 0.9827, Test Acc: 0.9730
# Epoch 4, Loss: 0.0605, Train Acc: 0.9888, Test Acc: 0.9797
# Epoch 5, Loss: 0.0428, Train Acc: 0.9904, Test Acc: 0.9770
# Epoch 6, Loss: 0.0331, Train Acc: 0.9935, Test Acc: 0.9794
# Epoch 7, Loss: 0.0260, Train Acc: 0.9935, Test Acc: 0.9793
# Epoch 8, Loss: 0.0187, Train Acc: 0.9955, Test Acc: 0.9780
# Epoch 9, Loss: 0.0158, Train Acc: 0.9962, Test Acc: 0.9805
# Epoch 10, Loss: 0.0125, Train Acc: 0.9981, Test Acc: 0.9799
# Epoch 11, Loss: 0.0115, Train Acc: 0.9977, Test Acc: 0.9813
# Epoch 12, Loss: 0.0103, Train Acc: 0.9955, Test Acc: 0.9787
# Epoch 13, Loss: 0.0112, Train Acc: 0.9980, Test Acc: 0.9806
# Epoch 14, Loss: 0.0080, Train Acc: 0.9975, Test Acc: 0.9789
# Epoch 15, Loss: 0.0083, Train Acc: 0.9976, Test Acc: 0.9792
# Epoch 16, Loss: 0.0081, Train Acc: 0.9970, Test Acc: 0.9791
# Epoch 17, Loss: 0.0090, Train Acc: 0.9961, Test Acc: 0.9785
# Epoch 18, Loss: 0.0063, Train Acc: 0.9990, Test Acc: 0.9815
# Epoch 19, Loss: 0.0023, Train Acc: 0.9995, Test Acc: 0.9816
# Epoch 20, Loss: 0.0088, Train Acc: 0.9962, Test Acc: 0.9788
# Epoch 21, Loss: 0.0108, Train Acc: 0.9982, Test Acc: 0.9799
# Epoch 22, Loss: 0.0032, Train Acc: 0.9997, Test Acc: 0.9805
# Epoch 23, Loss: 0.0045, Train Acc: 0.9988, Test Acc: 0.9806
# Epoch 24, Loss: 0.0051, Train Acc: 0.9994, Test Acc: 0.9815
# Epoch 25, Loss: 0.0063, Train Acc: 0.9976, Test Acc: 0.9803
# Epoch 26, Loss: 0.0042, Train Acc: 0.9996, Test Acc: 0.9832
# Epoch 27, Loss: 0.0012, Train Acc: 1.0000, Test Acc: 0.9835
# Epoch 28, Loss: 0.0001, Train Acc: 1.0000, Test Acc: 0.9853
# Epoch 29, Loss: 0.0001, Train Acc: 1.0000, Test Acc: 0.9849
# Epoch 30, Loss: 0.0000, Train Acc: 1.0000, Test Acc: 0.9851
# Epoch 31, Loss: 0.0000, Train Acc: 1.0000, Test Acc: 0.9852
# Epoch 32, Loss: 0.0000, Train Acc: 1.0000, Test Acc: 0.9850
# Epoch 33, Loss: 0.0000, Train Acc: 1.0000, Test Acc: 0.9850
# Epoch 34, Loss: 0.0000, Train Acc: 1.0000, Test Acc: 0.9850
# Epoch 35, Loss: 0.0000, Train Acc: 1.0000, Test Acc: 0.9851
# Epoch 36, Loss: 0.0000, Train Acc: 1.0000, Test Acc: 0.9851
# Epoch 37, Loss: 0.0000, Train Acc: 1.0000, Test Acc: 0.9849
# Epoch 38, Loss: 0.0000, Train Acc: 1.0000, Test Acc: 0.9849
# Epoch 39, Loss: 0.0000, Train Acc: 1.0000, Test Acc: 0.9848
# Epoch 40, Loss: 0.0000, Train Acc: 1.0000, Test Acc: 0.9851
# Epoch 41, Loss: 0.0000, Train Acc: 1.0000, Test Acc: 0.9852
# Epoch 42, Loss: 0.0000, Train Acc: 1.0000, Test Acc: 0.9851
# Epoch 43, Loss: 0.0000, Train Acc: 1.0000, Test Acc: 0.9850
# Epoch 44, Loss: 0.0000, Train Acc: 1.0000, Test Acc: 0.9850
# Epoch 45, Loss: 0.0000, Train Acc: 1.0000, Test Acc: 0.9852
# Epoch 46, Loss: 0.0000, Train Acc: 1.0000, Test Acc: 0.9850
# Epoch 47, Loss: 0.0000, Train Acc: 1.0000, Test Acc: 0.9852
# Epoch 48, Loss: 0.0000, Train Acc: 1.0000, Test Acc: 0.9851
# Epoch 49, Loss: 0.0000, Train Acc: 1.0000, Test Acc: 0.9850
# Epoch 50, Loss: 0.0000, Train Acc: 1.0000, Test Acc: 0.9852
# Epoch 51, Loss: 0.0000, Train Acc: 1.0000, Test Acc: 0.9854
# Epoch 52, Loss: 0.0000, Train Acc: 1.0000, Test Acc: 0.9853
# Epoch 53, Loss: 0.0000, Train Acc: 1.0000, Test Acc: 0.9855
# Epoch 54, Loss: 0.0000, Train Acc: 1.0000, Test Acc: 0.9853
# Epoch 55, Loss: 0.0000, Train Acc: 1.0000, Test Acc: 0.9855
# Epoch 56, Loss: 0.0000, Train Acc: 1.0000, Test Acc: 0.9851
# Epoch 57, Loss: 0.0000, Train Acc: 1.0000, Test Acc: 0.9855
# Epoch 58, Loss: 0.0000, Train Acc: 1.0000, Test Acc: 0.9853
# Epoch 59, Loss: 0.0000, Train Acc: 1.0000, Test Acc: 0.9854
# Epoch 60, Loss: 0.0000, Train Acc: 1.0000, Test Acc: 0.9854
# Epoch 61, Loss: 0.0000, Train Acc: 1.0000, Test Acc: 0.9852
# Epoch 62, Loss: 0.0000, Train Acc: 1.0000, Test Acc: 0.9855
# Epoch 63, Loss: 0.0000, Train Acc: 1.0000, Test Acc: 0.9855
# Epoch 64, Loss: 0.0000, Train Acc: 1.0000, Test Acc: 0.9853
# Epoch 65, Loss: 0.0000, Train Acc: 1.0000, Test Acc: 0.9855
# Epoch 66, Loss: 0.0000, Train Acc: 1.0000, Test Acc: 0.9853
# Epoch 67, Loss: 0.0000, Train Acc: 1.0000, Test Acc: 0.9854
# Epoch 68, Loss: 0.0000, Train Acc: 1.0000, Test Acc: 0.9851
# Epoch 69, Loss: 0.0000, Train Acc: 1.0000, Test Acc: 0.9853
# Epoch 70, Loss: 0.0000, Train Acc: 1.0000, Test Acc: 0.9855
# Epoch 71, Loss: 0.0000, Train Acc: 1.0000, Test Acc: 0.9853
# Epoch 72, Loss: 0.0000, Train Acc: 1.0000, Test Acc: 0.9850
# Epoch 73, Loss: 0.0000, Train Acc: 1.0000, Test Acc: 0.9855
# Epoch 74, Loss: 0.0000, Train Acc: 1.0000, Test Acc: 0.9852
# Epoch 75, Loss: 0.0000, Train Acc: 1.0000, Test Acc: 0.9852
# Epoch 76, Loss: 0.0000, Train Acc: 1.0000, Test Acc: 0.9853
# Epoch 77, Loss: 0.0000, Train Acc: 1.0000, Test Acc: 0.9852
# Epoch 78, Loss: 0.0000, Train Acc: 1.0000, Test Acc: 0.9851
# Epoch 79, Loss: 0.0000, Train Acc: 1.0000, Test Acc: 0.9850
# Epoch 80, Loss: 0.0000, Train Acc: 1.0000, Test Acc: 0.9850
# Epoch 81, Loss: 0.0000, Train Acc: 1.0000, Test Acc: 0.9855
# Epoch 82, Loss: 0.0000, Train Acc: 1.0000, Test Acc: 0.9852
# Epoch 83, Loss: 0.0000, Train Acc: 1.0000, Test Acc: 0.9848
# Epoch 84, Loss: 0.0000, Train Acc: 1.0000, Test Acc: 0.9848
# Epoch 85, Loss: 0.0000, Train Acc: 1.0000, Test Acc: 0.9847
# Epoch 86, Loss: 0.0000, Train Acc: 1.0000, Test Acc: 0.9845
# Epoch 87, Loss: 0.0000, Train Acc: 1.0000, Test Acc: 0.9850
# Epoch 88, Loss: 0.0000, Train Acc: 1.0000, Test Acc: 0.9851
# Epoch 89, Loss: 0.0000, Train Acc: 1.0000, Test Acc: 0.9846
# Epoch 90, Loss: 0.0000, Train Acc: 1.0000, Test Acc: 0.9846
# Epoch 91, Loss: 0.0000, Train Acc: 1.0000, Test Acc: 0.9850
# Epoch 92, Loss: 0.0000, Train Acc: 1.0000, Test Acc: 0.9848
# Epoch 93, Loss: 0.0000, Train Acc: 1.0000, Test Acc: 0.9847
# Epoch 94, Loss: 0.0000, Train Acc: 1.0000, Test Acc: 0.9850
# Epoch 95, Loss: 0.0000, Train Acc: 1.0000, Test Acc: 0.9851
# Epoch 96, Loss: 0.0000, Train Acc: 1.0000, Test Acc: 0.9848
# Epoch 97, Loss: 0.0000, Train Acc: 1.0000, Test Acc: 0.9849
# Epoch 98, Loss: 0.0000, Train Acc: 1.0000, Test Acc: 0.9849
# Epoch 99, Loss: 0.0000, Train Acc: 1.0000, Test Acc: 0.9850
# Epoch 100, Loss: 0.0000, Train Acc: 1.0000, Test Acc: 0.9850

# %%
import torch
import torchvision
import torchvision.transforms as transforms

# %% [markdown]
# 다음은 dataset을 준비합니다. 손글씨 dataset은 MNIST라는 유명한 dataset이 있습니다. 이 dataset은 `torchvision`에서 제공하고 있으며, 다음과 같이 다운로드 받을 수 있습니다.

# %%
transform = transforms.ToTensor()

trainset = torchvision.datasets.MNIST(
    root='./data',
    train=False,
    download=True,
    transform=transform
)

# %%
# 테스트 데이터 로드
testset = torchvision.datasets.MNIST(
    root='./data',
    train=False,
    download=True,
    transform=transform
)

# %% [markdown]
# MNIST는 손글씨 사진과 어떤 숫자를 의미하는지에 대한 label의 pair들로 구성되어있습니다.
# 이 때, 우리는 PyTorch model을 사용할 것이기 때문에 손글씨 사진들을 모두 tensor로 변환해야합니다.
# 이러한 부가적인 변환들은 `torchvision.transforms`에서 제공하고 있으며, `torchvision.datasets.MNIST`에서 `transform` 인자로 받을 수 있습니다.
# 우리는 단순히 사진을 tensor로 바꾸고 싶기 때문에 `transforms.ToTensor()` transformation을 넘겨줍니다.
#
# 다음은 전체 data의 개수와 첫 번째 data를 출력한 결과입니다.

# %%
from matplotlib import pyplot as plt


print(len(trainset))
print(trainset[0][0].shape, trainset[0][1])
plt.imshow(trainset[0][0][0], cmap='gray')
# Out:
# 10000
# torch.Size([1, 28, 28]) 7

# %% [markdown]
# 첫 번째 출력결과를 통해 우리는 6만장의 손글씨 data가 있는 것을 알 수 있습니다.
# 그리고 두 번째 출력결과를 통해 첫 번째 data의 shape은 (1, 28, 28)이고 5라는 숫자를 쓴 사진이라는 것을 알 수 있습니다.
# 마지막으로 `plt.imshow`를 통해 visualize 했을 때 5라는 숫자가 나오는 것을 알 수 있습니다.
#
# 다음은 SGD를 위해 dataset을 여러 개의 batch로 나누는 과정을 PyTorch로 구현한 모습입니다.

# %%
batch_size = 64

# 테스트 데이터 로더 생성
testloader = torch.utils.data.DataLoader(
    testset,
    batch_size=batch_size,
    shuffle=False
)

# %% [markdown]
# PyTorch에서는 `DataLoader`가 dataset을 인자로 받아 batch로 나눠줍니다.
# 부가적으로 `batch_size`라는 인자를 통해 batch size를 받고 있으며, `shuffle`이라는 인자를 통해 data들을 섞을지 결정해줍니다.
# 우리는 SGD가 완전 랜덤으로 batch를 구성해야 잘 동작하는 것을 알고 있기 때문에 `shuffle`에 `True`를 넘겨주고 있습니다.
#
# 다음은 첫 번째 batch를 출력한 모습입니다.

# %%
dataiter = iter(trainloader)
images, labels = next(dataiter)
print(images.shape, labels.shape)
# Out:
# torch.Size([64, 1, 28, 28]) torch.Size([64])

# %% [markdown]
# `images`는 첫 번째 batch의 image들이고 `labels`는 첫 번째 batch의 label들입니다.
# 위에서 batch size를 64로 설정했기 때문에 총 64개의 image와 label들이 있어야 합니다.
# 실제 shape 출력 결과를 보면 그렇다는 것을 알 수 있습니다.
#
# 다음은 (n, 1, 28, 28) shape의 image를 입력받아 0~9 사이의 정수 하나를 출력하는 3-layer MLP를 구현합니다.

# %%
from torch import nn


class Model(nn.Module):
  def __init__(self):
    super().__init__()

    self.fc1 = nn.Linear(28*28, 512)
    self.fc2 = nn.Linear(512, 256)
    self.fc3 = nn.Linear(256, 10)  # 출력: 10개 클래스

  def forward(self, x):
    x = x.view(-1, 28*28)  # flatten
    x = F.relu(self.fc1(x))
    x = F.relu(self.fc2(x))
    x = self.fc3(x)  # 마지막에는 ReLU 제거, softmax는 CrossEntropyLoss에 포함됨

    return x

model = Model().to(device)


# model = Model(28 * 28 * 1, 1024)

# %% [markdown]
# 이전의 2-layer MLP와 유사한 형태임을 알 수 있습니다.
# 여기서 특이사항은 `forward`의 첫 번째 줄에 `torch.flatten`을 사용한다는 것입니다.
# `Linear`는 이전에도 봤다시피 (n, d) 형태의 shape을 입력받습니다.
# 이미지는 (n, 1, 28, 28)이기 때문에 (n, 1 * 28 * 28)로 shape을 변환해야 선형 함수에 입력으로 주어줄 수 있게 됩니다.
# 이 역할을 수행하는 것이 바로 `torch.flatten`입니다.
# 우리는 첫 번째 shape인 n을 보존할 것이기 때문에 flatten할 차원은 `start_dim=1`로 넘겨주게 됩니다.
#
# 다음은 gradient descent를 수행해줄 optimizer를 구현하는 모습입니다.

# %%
from torch.optim import SGD
import torch

# M1/M2/M3 맥북에서 MPS 사용할 수 있게 장치 설정
device = torch.device("mps" if torch.backends.mps.is_available() else "cpu")

lr = 0.001

# 모델 생성 예시 (예: 간단한 linear model)
model = torch.nn.Linear(10, 1)

# 모델을 적절한 장치로 이동 (mps or cpu)
model = model.to(device)

# Optimizer 설정
optimizer = SGD(model.parameters(), lr=lr)

# %% [markdown]
# 이전 코드와 거의 똑같습니다. 다른 점은 `model.to('cuda')` 코드를 통해 우리가 구현한 model을 GPU로 옮긴 것입니다.
# MNIST 부터는 모델과 data가 커지면서 훨씬 많은 행렬 연산이 이루어지기 때문에 GPU를 활용하는 것이 빠릅니다.
#
# 다음은 model을 MNIST에 학습하는 코드입니다.

# %%
import torch
from torch import nn
from torch.optim import SGD

# MPS 또는 CPU 자동 선택
device = torch.device("mps" if torch.backends.mps.is_available() else "cpu")

# 예시 모델
model = nn.Linear(784, 1)
model = model.to(device)

# 옵티마이저
optimizer = SGD(model.parameters(), lr=0.001)

# 에폭 루프
for epoch in range(100):
    total_loss = 0.
    for data in trainloader:
        inputs, labels = data
        
        # 입력을 device로 이동 (중요!)
        inputs, labels = inputs.to(device), labels.to(device)

        # Flatten (MNIST 같은 경우)
        inputs = inputs.view(inputs.size(0), -1)

        model.zero_grad()
        preds = model(inputs)
        loss = (preds[:, 0] - labels).pow(2).mean()

        loss.backward()
        optimizer.step()

        total_loss += loss.item()

    print(f"Epoch {epoch:3d} | Loss: {total_loss:.4f}")
# Out:
# Epoch   0 | Loss: 4776.3927
# Epoch   1 | Loss: 3882.8116
# Epoch   2 | Loss: 3683.8231
# Epoch   3 | Loss: 3554.4366
# Epoch   4 | Loss: 3462.0066
# Epoch   5 | Loss: 3391.9133
# Epoch   6 | Loss: 3336.7328
# Epoch   7 | Loss: 3292.7889
# Epoch   8 | Loss: 3258.9149
# Epoch   9 | Loss: 3230.8969
# Epoch  10 | Loss: 3208.7435
# Epoch  11 | Loss: 3188.2257
# Epoch  12 | Loss: 3173.3765
# Epoch  13 | Loss: 3159.9602
# Epoch  14 | Loss: 3149.4031
# Epoch  15 | Loss: 3139.6461
# Epoch  16 | Loss: 3130.6912
# Epoch  17 | Loss: 3122.9681
# Epoch  18 | Loss: 3118.3501
# Epoch  19 | Loss: 3111.8574
# Epoch  20 | Loss: 3107.4701
# Epoch  21 | Loss: 3103.2947
# Epoch  22 | Loss: 3099.3515
# Epoch  23 | Loss: 3095.2382
# Epoch  24 | Loss: 3092.0698
# Epoch  25 | Loss: 3089.6642
# Epoch  26 | Loss: 3087.2421
# Epoch  27 | Loss: 3084.0637
# Epoch  28 | Loss: 3081.1601
# Epoch  29 | Loss: 3079.9851
# Epoch  30 | Loss: 3077.1580
# Epoch  31 | Loss: 3076.0704
# Epoch  32 | Loss: 3074.8589
# Epoch  33 | Loss: 3072.7148
# Epoch  34 | Loss: 3070.7419
# Epoch  35 | Loss: 3069.8210
# Epoch  36 | Loss: 3068.0681
# Epoch  37 | Loss: 3067.5416
# Epoch  38 | Loss: 3065.9548
# Epoch  39 | Loss: 3064.7287
# Epoch  40 | Loss: 3063.6436
# Epoch  41 | Loss: 3061.7164
# Epoch  42 | Loss: 3060.3555
# Epoch  43 | Loss: 3060.7391
# Epoch  44 | Loss: 3059.4717
# Epoch  45 | Loss: 3060.6462
# Epoch  46 | Loss: 3057.4582
# Epoch  47 | Loss: 3057.1721
# Epoch  48 | Loss: 3056.4283
# Epoch  49 | Loss: 3055.1390
# Epoch  50 | Loss: 3054.2562
# Epoch  51 | Loss: 3053.8191
# Epoch  52 | Loss: 3053.7151
# Epoch  53 | Loss: 3051.3620
# Epoch  54 | Loss: 3051.8150
# Epoch  55 | Loss: 3050.6388
# Epoch  56 | Loss: 3051.4106
# Epoch  57 | Loss: 3049.8872
# Epoch  58 | Loss: 3050.1831
# Epoch  59 | Loss: 3049.1551
# Epoch  60 | Loss: 3048.5975
# Epoch  61 | Loss: 3048.6046
# Epoch  62 | Loss: 3047.0634
# Epoch  63 | Loss: 3046.8632
# Epoch  64 | Loss: 3048.2086
# Epoch  65 | Loss: 3046.4490
# Epoch  66 | Loss: 3045.5503
# Epoch  67 | Loss: 3045.8313
# Epoch  68 | Loss: 3045.6653
# Epoch  69 | Loss: 3045.0257
# Epoch  70 | Loss: 3044.5775
# Epoch  71 | Loss: 3043.5812
# Epoch  72 | Loss: 3044.3784
# Epoch  73 | Loss: 3043.4797
# Epoch  74 | Loss: 3042.4851
# Epoch  75 | Loss: 3042.7076
# Epoch  76 | Loss: 3042.0962
# Epoch  77 | Loss: 3041.6919
# Epoch  78 | Loss: 3042.3688
# Epoch  79 | Loss: 3041.2217
# Epoch  80 | Loss: 3041.3222
# Epoch  81 | Loss: 3040.4199
# Epoch  82 | Loss: 3038.8832
# Epoch  83 | Loss: 3041.5708
# Epoch  84 | Loss: 3040.2748
# Epoch  85 | Loss: 3040.0560
# Epoch  86 | Loss: 3040.1983
# Epoch  87 | Loss: 3039.2598
# Epoch  88 | Loss: 3039.2241
# Epoch  89 | Loss: 3039.1631
# Epoch  90 | Loss: 3038.2369
# Epoch  91 | Loss: 3038.4699
# Epoch  92 | Loss: 3036.9564
# Epoch  93 | Loss: 3037.6572
# Epoch  94 | Loss: 3037.1728
# Epoch  95 | Loss: 3038.3168
# Epoch  96 | Loss: 3038.0290
# Epoch  97 | Loss: 3036.7935
# Epoch  98 | Loss: 3038.0961
# Epoch  99 | Loss: 3036.1489

# %% [markdown]
# 출력 결과를 보면 잘 수렴하는 것을 볼 수 있습니다.
# 이전 구현과 다른 점은 다음 두 가지입니다.
# - `for data in trainloader`를 통해 batch들을 iterate하면서 model을 학습합니다.
# - `inputs, labels = inputs.to('cuda'), labels.to('cuda')`를 통해 model의 입력으로 들어가는 tensor들을 GPU로 보냅니다.
#
# 마지막으로 첫 번째 data에 대한 예측 결과를 살펴봅시다.

# %%
idx = 0

# 입력 이미지 (1, 28, 28) → (1, 1, 28, 28)
x = trainset[idx][0][None]  

# MPS 또는 CPU로 전송
x = x.to(device)

# flatten 해줘야 Linear(784, 1)에 들어갈 수 있어
x = x.view(x.size(0), -1)  # (1, 784)

# 모델도 device로 옮겨져 있어야 함!
model.eval()
with torch.no_grad():
    print(model(x))  # 예측값 출력

print(trainset[idx][1])  # 실제 레이블
# Out:
# tensor([[6.2696]], device='mps:0')
# 7

# %% [markdown]
# 여기서 idx를 조정하여 다른 data에 대한 출력 결과도 볼 수 있습니다.
# 예측 결과를 보시면 아직 성능이 그렇게 좋지 않은 것을 알 수 있습니다.

# %%
# 정확도 측정 함수 추가
def accuracy(model, dataloader):
  cnt = 0
  acc = 0

  for data in dataloader:
    inputs, labels = data
    inputs, labels = inputs.to(device), labels.to(device)

    preds = model(inputs)
    preds = torch.argmax(preds, dim=-1)

    cnt += labels.shape[0]
    acc += (labels == preds).sum().item()

  return acc / cnt


print(accuracy(model, testloader))
# Out:
# ---------------------------------------------------------------------------
#
# RuntimeError                              Traceback (most recent call last)
#
# Cell In[38], line 19
#
#      14     acc += (labels == preds).sum().item()
#
#      16   return acc / cnt
#
# ---> 19 print(accuracy(model, testloader))
#
#
#
# Cell In[38], line 10, in accuracy(model, dataloader)
#
#       7 inputs, labels = data
#
#       8 inputs, labels = inputs.to(device), labels.to(device)
#
# ---> 10 preds = model(inputs)
#
#      11 preds = torch.argmax(preds, dim=-1)
#
#      13 cnt += labels.shape[0]
#
#
#
# File ~/Documents/b2b/data_analyze/.conda/lib/python3.12/site-packages/torch/nn/modules/module.py:1739, in Module._wrapped_call_impl(self, *args, **kwargs)
#
#    1737     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#
#    1738 else:
#
# -> 1739     return self._call_impl(*args, **kwargs)
#
#
#
# File ~/Documents/b2b/data_analyze/.conda/lib/python3.12/site-packages/torch/nn/modules/module.py:1750, in Module._call_impl(self, *args, **kwargs)
#
#    1745 # If we don't have any hooks, we want to skip the rest of the logic in
#
#    1746 # this function, and just call forward.
#
#    1747 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#
#    1748         or _global_backward_pre_hooks or _global_backward_hooks
#
#    1749         or _global_forward_hooks or _global_forward_pre_hooks):
#
# -> 1750     return forward_call(*args, **kwargs)
#
#    1752 result = None
#
#    1753 called_always_called_hooks = set()
#
#
#
# File ~/Documents/b2b/data_analyze/.conda/lib/python3.12/site-packages/torch/nn/modules/linear.py:125, in Linear.forward(self, input)
#
#     124 def forward(self, input: Tensor) -> Tensor:
#
# --> 125     return F.linear(input, self.weight, self.bias)
#
#
#
# RuntimeError: linear(): input and weight.T shapes cannot be multiplied (28x28 and 784x1)
